# %% [markdown]
# # Dataframes
#
# Um DataFrame é uma das estruturas de dados mais importantes e amplamente utilizadas na biblioteca Pandas do Python. Ele é essencialmente uma tabela bidimensional, semelhante a uma planilha do Excel ou uma tabela de banco de dados, onde os dados são organizados em linhas e colunas.
#
# Principais Características de um DataFrame:
# 1. **Estrutura Bidimensional**: Os dados são organizados em linhas e colunas.
#
# 2. **Rotulagem**: Tanto as linhas quanto as colunas podem ser rotuladas, o que facilita o acesso e a manipulação dos dados.
#
# 3. **Tipos de Dados Diversos**: Cada coluna pode conter diferentes tipos de dados   (números, strings, booleanos, etc.).

# %%
import pandas as pd

# Crio um dicionário onde a chave é o nome de uma pessoa e o valor é uma lista com: [cpf, endereço, telefone, idade]
cadastro = {
    'Ana Silva': ['123.456.789-00', 'Rua das Flores, 123, São Paulo, SP', '(11) 98765-4321', 28],
    'Bruno Souza': ['987.654.321-00', 'Avenida Brasil, 456, Rio de Janeiro, RJ', '(21) 91234-5678', 35],
    'Carlos Pereira': ['456.789.123-00', 'Praça da Sé, 789, Fortaleza, CE', '(85) 99876-5432', 42],
    'Daniela Costa': ['321.654.987-00', 'Rua das Palmeiras, 321, Belo Horizonte, MG', '(31) 91234-5678', 30],
    'Eduardo Lima': ['654.321.987-00', 'Avenida Paulista, 654, São Paulo, SP', '(11) 99876-5432', 40],
    'Fernanda Oliveira': ['789.123.456-00', 'Rua da Praia, 789, Salvador, BA', '(71) 98765-4321', 27],
    'Gabriel Santos': ['987.123.654-00', 'Avenida Atlântica, 987, Rio de Janeiro, RJ', '(21) 91234-5678', 33],
    'Helena Martins': ['123.789.456-00', 'Rua das Acácias, 123, Curitiba, PR', '(41) 99876-5432', 29],
    'Igor Almeida': ['456.123.789-00', 'Avenida das Américas, 456, Brasília, DF', '(61) 98765-4321', 38],
    'Juliana Ferreira': ['789.456.123-00', 'Rua das Laranjeiras, 789, Recife, PE', '(81) 91234-5678', 31],
    'Lucas Rocha': ['321.987.654-00', 'Avenida Central, 321, Porto Alegre, RS', '(51) 99876-5432', 36],
    'Mariana Gomes': ['654.987.321-00', 'Rua das Palmeiras, 654, Manaus, AM', '(92) 98765-4321', 25],
    'Nicolas Ribeiro': ['987.654.123-00', 'Avenida Beira Mar, 987, Fortaleza, CE', '(85) 91234-5678', 34],
    'Olivia Mendes': ['123.654.789-00', 'Rua das Hortênsias, 123, Florianópolis, SC', '(48) 99876-5432', 28],
    'Pedro Araujo': ['456.987.123-00', 'Avenida Independência, 456, Goiânia, GO', '(62) 98765-4321', 37],
    'Quintino Barbosa': ['789.321.654-00', 'Rua das Rosas, 789, Vitória, ES', '(27) 91234-5678', 32],
    'Rafaela Nunes': ['321.456.987-00', 'Avenida das Nações, 321, Natal, RN', '(84) 99876-5432', 26],
    'Samuel Cardoso': ['654.123.987-00', 'Rua das Mangueiras, 654, João Pessoa, PB', '(83) 98765-4321', 39],
    'Tatiana Lopes': ['987.321.456-00', 'Avenida do Contorno, 987, Maceió, AL', '(82) 91234-5678', 30],
    'Ursula Vieira': ['123.987.654-00', 'Rua das Oliveiras, 123, Teresina, PI', '(86) 99876-5432', 27],
    'Vinicius Moreira': ['654.789.321-00', 'Avenida das Palmeiras, 654, Belém, PA', '(91) 98765-4321', 41]
}

# Transformando o dicionário em um DataFrame para manipulação com pandas.
df = pd.DataFrame(cadastro)

# Exibindo na Transversal
df
# Out:
#                             Ana Silva  \
# 0                      123.456.789-00
# 1  Rua das Flores, 123, São Paulo, SP
# 2                     (11) 98765-4321
# 3                                  28
#
#                                Bruno Souza                   Carlos Pereira  \
# 0                           987.654.321-00                   456.789.123-00
# 1  Avenida Brasil, 456, Rio de Janeiro, RJ  Praça da Sé, 789, Fortaleza, CE
# 2                          (21) 91234-5678                  (85) 99876-5432
# 3                                       35                               42
#
#                                 Daniela Costa  \
# 0                              321.654.987-00
# 1  Rua das Palmeiras, 321, Belo Horizonte, MG
# 2                             (31) 91234-5678
# 3                                          30
#
#                            Eduardo Lima                Fernanda Oliveira  \
# 0                        654.321.987-00                   789.123.456-00
# ...

# %%
# exibindo informações do dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ana Silva          4 non-null      object
#  1   Bruno Souza        4 non-null      object
#  2   Carlos Pereira     4 non-null      object
#  3   Daniela Costa      4 non-null      object
#  4   Eduardo Lima       4 non-null      object
#  5   Fernanda Oliveira  4 non-null      object
#  6   Gabriel Santos     4 non-null      object
#  7   Helena Martins     4 non-null      object
#  8   Igor Almeida       4 non-null      object
#  9   Juliana Ferreira   4 non-null      object
#  10  Lucas Rocha        4 non-null      object
#  11  Mariana Gomes      4 non-null      object
#  12  Nicolas Ribeiro    4 non-null      object
#  13  Olivia Mendes      4 non-null      object
#  14  Pedro Araujo       4 non-null      object
#  15  Quintino Barbosa   4 non-null      object
# ...

# %%
# Quantidade exata de memória alocada.
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ana Silva          4 non-null      object
#  1   Bruno Souza        4 non-null      object
#  2   Carlos Pereira     4 non-null      object
#  3   Daniela Costa      4 non-null      object
#  4   Eduardo Lima       4 non-null      object
#  5   Fernanda Oliveira  4 non-null      object
#  6   Gabriel Santos     4 non-null      object
#  7   Helena Martins     4 non-null      object
#  8   Igor Almeida       4 non-null      object
#  9   Juliana Ferreira   4 non-null      object
#  10  Lucas Rocha        4 non-null      object
#  11  Mariana Gomes      4 non-null      object
#  12  Nicolas Ribeiro    4 non-null      object
#  13  Olivia Mendes      4 non-null      object
#  14  Pedro Araujo       4 non-null      object
#  15  Quintino Barbosa   4 non-null      object
# ...

# %%
# Exibe as informações dos tipos de cada coluna.
df.dtypes
# Out:
# Ana Silva            object
# Bruno Souza          object
# Carlos Pereira       object
# Daniela Costa        object
# Eduardo Lima         object
# Fernanda Oliveira    object
# Gabriel Santos       object
# Helena Martins       object
# Igor Almeida         object
# Juliana Ferreira     object
# Lucas Rocha          object
# Mariana Gomes        object
# Nicolas Ribeiro      object
# Olivia Mendes        object
# Pedro Araujo         object
# Quintino Barbosa     object
# Rafaela Nunes        object
# Samuel Cardoso       object
# Tatiana Lopes        object
# Ursula Vieira        object
# Vinicius Moreira     object
# dtype: object

# %%
df.describe().T
# Out:
#                   count unique             top freq
# Ana Silva             4      4  123.456.789-00    1
# Bruno Souza           4      4  987.654.321-00    1
# Carlos Pereira        4      4  456.789.123-00    1
# Daniela Costa         4      4  321.654.987-00    1
# Eduardo Lima          4      4  654.321.987-00    1
# Fernanda Oliveira     4      4  789.123.456-00    1
# Gabriel Santos        4      4  987.123.654-00    1
# Helena Martins        4      4  123.789.456-00    1
# Igor Almeida          4      4  456.123.789-00    1
# Juliana Ferreira      4      4  789.456.123-00    1
# Lucas Rocha           4      4  321.987.654-00    1
# Mariana Gomes         4      4  654.987.321-00    1
# Nicolas Ribeiro       4      4  987.654.123-00    1
# Olivia Mendes         4      4  123.654.789-00    1
# Pedro Araujo          4      4  456.987.123-00    1
# Quintino Barbosa      4      4  789.321.654-00    1
# Rafaela Nunes         4      4  321.456.987-00    1
# ...

# %%
# alterando os índices
df.index = ['cpf', 'endereco', 'telefone', 'idade']

# Alterando a visualização
df.T
# Out:
#                               cpf                                    endereco  \
# Ana Silva          123.456.789-00          Rua das Flores, 123, São Paulo, SP
# Bruno Souza        987.654.321-00     Avenida Brasil, 456, Rio de Janeiro, RJ
# Carlos Pereira     456.789.123-00             Praça da Sé, 789, Fortaleza, CE
# Daniela Costa      321.654.987-00  Rua das Palmeiras, 321, Belo Horizonte, MG
# Eduardo Lima       654.321.987-00        Avenida Paulista, 654, São Paulo, SP
# Fernanda Oliveira  789.123.456-00             Rua da Praia, 789, Salvador, BA
# Gabriel Santos     987.123.654-00  Avenida Atlântica, 987, Rio de Janeiro, RJ
# Helena Martins     123.789.456-00          Rua das Acácias, 123, Curitiba, PR
# Igor Almeida       456.123.789-00     Avenida das Américas, 456, Brasília, DF
# Juliana Ferreira   789.456.123-00        Rua das Laranjeiras, 789, Recife, PE
# Lucas Rocha        321.987.654-00      Avenida Central, 321, Porto Alegre, RS
# ...

# %%
# Exibindo os dados de uma pessoa
df['Ana Silva']
# Out:
# cpf                             123.456.789-00
# endereco    Rua das Flores, 123, São Paulo, SP
# telefone                       (11) 98765-4321
# idade                                       28
# Name: Ana Silva, dtype: object

# %%
# Buscando a idade da primeira pessoa no DataFrame
df['Ana Silva'][3]
# Out:
# /tmp/ipykernel_9073/3521732620.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['Ana Silva'][3]
# 28

# %%
# Utilizando Iloc
# Recuperando endereço

df['Pedro Araujo'].iloc[1]
# Out:
# 'Avenida Independência, 456, Goiânia, GO'

# %%
df.T['idade']
# Out:
# Ana Silva            28
# Bruno Souza          35
# Carlos Pereira       42
# Daniela Costa        30
# Eduardo Lima         40
# Fernanda Oliveira    27
# Gabriel Santos       33
# Helena Martins       29
# Igor Almeida         38
# Juliana Ferreira     31
# Lucas Rocha          36
# Mariana Gomes        25
# Nicolas Ribeiro      34
# Olivia Mendes        28
# Pedro Araujo         37
# Quintino Barbosa     32
# Rafaela Nunes        26
# Samuel Cardoso       39
# Tatiana Lopes        30
# Ursula Vieira        27
# Vinicius Moreira     41
# Name: idade, dtype: object

# %% [markdown]
# #### Exemplos do Theo

# %%
data = {
    "nome":["jhon", "nah", "lara", "maria"],
    "sobrenome": ["costa", "ataide", "silva", "josé"],
    "idade": [35, 54, 21, 19]
    }

# %%
import pandas as pd 

df = pd.DataFrame(data)

df
# Out:
#     nome sobrenome  idade
# 0   jhon     costa     35
# 1    nah    ataide     54
# 2   lara     silva     21
# 3  maria      josé     19

# %%
# Selecionando as colunas que eu quero
idades = df[["nome", "idade"]]
idades
# Out:
#     nome  idade
# 0   jhon     35
# 1    nah     54
# 2   lara     21
# 3  maria     19

# %%
# Exibindo os indices
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# Exibindo as colunas
df.columns
# Out:
# Index(['nome', 'sobrenome', 'idade'], dtype='object')

# %%
# Info exir informações
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nome       4 non-null      object
#  1   sobrenome  4 non-null      object
#  2   idade      4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
# Info exir informações, com detalhes de espaço em memória
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nome       4 non-null      object
#  1   sobrenome  4 non-null      object
#  2   idade      4 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 608.0 bytes

# %%
df.describe()
# Out:
#            idade
# count   4.000000
# mean   32.250000
# std    16.152915
# min    19.000000
# 25%    20.500000
# 50%    28.000000
# 75%    39.750000
# max    54.000000

# %%
# Exibe o inicio do dataframe, o default é 5 linhas, mas pode ser especificado esse parâmetro
df.head(2)
# Out:
#    nome sobrenome  idade
# 0  jhon     costa     35
# 1   nah    ataide     54

# %%
# Exibe o final do dataframe, o default é 5 linhas, mas pode ser especificado esse parâmetro
df.tail(2)
# Out:
#     nome sobrenome  idade
# 2   lara     silva     21
# 3  maria      josé     19
